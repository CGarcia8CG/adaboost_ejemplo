# %%
import numpy as np
import pandas as pd

# %%
# Ajuste Pandas
pd.set_option('display.max_columns', None)

# %%
def open_csv_data() -> pd.DataFrame:
    '''
    Function for open the data from a csv
    Input: None
    Returns: Pandas DataFrame

    '''
    path = '..\input\Score.csv'
    df = pd.read_csv(path)
    return df

df = open_csv_data()
df.head(10)
# Out:
#    Delay_from_due_date  Num_of_Delayed_Payment  Num_Credit_Inquiries  \
# 0                  3.0                     7.0                   4.0
# 1                  3.0                     7.0                   4.0
# 2                  3.0                     7.0                   4.0
# 3                  5.0                     4.0                   4.0
# 4                  6.0                     4.0                   4.0
# 5                  8.0                     4.0                   4.0
# 6                  3.0                     8.0                   4.0
# 7                  3.0                     6.0                   4.0
# 8                  3.0                     4.0                   2.0
# 9                  7.0                     1.0                   2.0
#
#    Credit_Utilization_Ratio  Credit_History_Age Payment_of_Min_Amount  \
# 0                 26.822620               265.0                    No
# ...

# %%
def numerical_data_transform() -> pd.DataFrame:
'''
Escalar datos numericos
Input: Pandas DataFrame
Returns: Pandas DataFrame
'''
    return None
